# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('japan_birth.csv')
df
# Out:
#      Unnamed: 0  year  birth_total  birth_male  birth_female  birth_rate  \
# 0             0  1899    1386981.0    713442.0      673539.0        32.0
# 1             1  1900    1420534.0    727916.0      692618.0        32.4
# 2             2  1901    1501591.0    769494.0      732097.0        33.9
# 3             3  1902    1510835.0    773296.0      737539.0        33.6
# 4             4  1903    1489816.0    763806.0      726010.0        32.7
# ..          ...   ...          ...         ...           ...         ...
# 119         119  2018     918400.0    470851.0      447549.0         7.4
# 120         120  2019     865239.0    443430.0      421809.0         7.0
# 121         121  2020     840835.0    430713.0      410122.0         6.8
# 122         122  2021     811622.0    415903.0      395719.0         6.6
# 123         123  2022     770759.0    395257.0      375502.0         6.3
#
#      birth_gender_ratio  total_fertility_rate  population_total  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         year   birth_total    birth_male  birth_female  \
# count  124.000000   124.000000  1.210000e+02  1.210000e+02  1.210000e+02
# mean    61.500000  1960.500000  1.626691e+06  8.342706e+05  7.924202e+05
# std     35.939764    35.939764  4.334684e+05  2.219274e+05  2.115989e+05
# min      0.000000  1899.000000  7.707590e+05  3.952570e+05  3.755020e+05
# 25%     30.750000  1929.750000  1.221585e+06  6.269710e+05  5.946140e+05
# 50%     61.500000  1960.500000  1.659521e+06  8.502090e+05  8.069600e+05
# 75%     92.250000  1991.250000  1.990876e+06  1.017457e+06  9.680360e+05
# max    123.000000  2022.000000  2.696638e+06  1.380008e+06  1.316630e+06
#
#        birth_rate  birth_gender_ratio  total_fertility_rate  population_total  \
# count  121.000000          121.000000             76.000000      1.240000e+02
# mean    20.947107          105.312397              1.869474      9.140094e+07
# ...
